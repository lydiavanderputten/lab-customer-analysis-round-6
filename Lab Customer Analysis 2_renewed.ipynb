# %%
import pandas as pd

# %%
file1=pd.read_csv('files_for_lab/csv_files/marketing_customer_analysis.csv')

# %%
file1.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
file1.shape
# Out:
# (10910, 26)

# %%
file1.dtypes
file1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
file1._get_numeric_data()
# Out:
#        Unnamed: 0  Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# ...

# %%
file1.isna().sum()
# Out:
# Unnamed: 0                          0
# Customer                            0
# State                             631
# Customer Lifetime Value             0
# Response                          631
# Coverage                            0
# Education                           0
# Effective To Date                   0
# EmploymentStatus                    0
# Gender                              0
# Income                              0
# Location Code                       0
# Marital Status                      0
# Monthly Premium Auto                0
# Months Since Last Claim           633
# Months Since Policy Inception       0
# Number of Open Complaints         633
# Number of Policies                  0
# Policy Type                         0
# Policy                              0
# Renew Offer Type                    0
# Sales Channel                       0
# Total Claim Amount                  0
# Vehicle Class                     622
# Vehicle Size                      622
# ...

# %%
round(file1.isna().sum()/len(file1),4)*100
# Out:
# Unnamed: 0                        0.00
# Customer                          0.00
# State                             5.78
# Customer Lifetime Value           0.00
# Response                          5.78
# Coverage                          0.00
# Education                         0.00
# Effective To Date                 0.00
# EmploymentStatus                  0.00
# Gender                            0.00
# Income                            0.00
# Location Code                     0.00
# Marital Status                    0.00
# Monthly Premium Auto              0.00
# Months Since Last Claim           5.80
# Months Since Policy Inception     0.00
# Number of Open Complaints         5.80
# Number of Policies                0.00
# Policy Type                       0.00
# Policy                            0.00
# Renew Offer Type                  0.00
# Sales Channel                     0.00
# Total Claim Amount                0.00
# Vehicle Class                     5.70
# ...

# %%
nulls_df = pd.DataFrame(round(file1.isna().sum()/len(file1),4)*100)

# %%
nulls_df
# Out:
#                                    0
# Unnamed: 0                      0.00
# Customer                        0.00
# State                           5.78
# Customer Lifetime Value         0.00
# Response                        5.78
# Coverage                        0.00
# Education                       0.00
# Effective To Date               0.00
# EmploymentStatus                0.00
# Gender                          0.00
# Income                          0.00
# Location Code                   0.00
# Marital Status                  0.00
# Monthly Premium Auto            0.00
# Months Since Last Claim         5.80
# Months Since Policy Inception   0.00
# Number of Open Complaints       5.80
# Number of Policies              0.00
# Policy Type                     0.00
# Policy                          0.00
# Renew Offer Type                0.00
# Sales Channel                   0.00
# Total Claim Amount              0.00
# Vehicle Class                   5.70
# ...

# %%
nulls_df = nulls_df.reset_index()

# %%
nulls_df
# Out:
#                             index      0
# 0                      Unnamed: 0   0.00
# 1                        Customer   0.00
# 2                           State   5.78
# 3         Customer Lifetime Value   0.00
# 4                        Response   5.78
# 5                        Coverage   0.00
# 6                       Education   0.00
# 7               Effective To Date   0.00
# 8                EmploymentStatus   0.00
# 9                          Gender   0.00
# 10                         Income   0.00
# 11                  Location Code   0.00
# 12                 Marital Status   0.00
# 13           Monthly Premium Auto   0.00
# 14        Months Since Last Claim   5.80
# 15  Months Since Policy Inception   0.00
# 16      Number of Open Complaints   5.80
# 17             Number of Policies   0.00
# 18                    Policy Type   0.00
# 19                         Policy   0.00
# 20               Renew Offer Type   0.00
# 21                  Sales Channel   0.00
# ...

# %%
nulls_df.columns = ['Column Labels', 'percent_nulls']

# %%
nulls_df
# Out:
#                     Column Labels  percent_nulls
# 0                      Unnamed: 0           0.00
# 1                        Customer           0.00
# 2                           State           5.78
# 3         Customer Lifetime Value           0.00
# 4                        Response           5.78
# 5                        Coverage           0.00
# 6                       Education           0.00
# 7               Effective To Date           0.00
# 8                EmploymentStatus           0.00
# 9                          Gender           0.00
# 10                         Income           0.00
# 11                  Location Code           0.00
# 12                 Marital Status           0.00
# 13           Monthly Premium Auto           0.00
# 14        Months Since Last Claim           5.80
# 15  Months Since Policy Inception           0.00
# 16      Number of Open Complaints           5.80
# 17             Number of Policies           0.00
# ...

# %%
#I decided to drop the columns with a lot (the most) NaN values 
file1 = file1.drop('Vehicle Type', axis=1) 
# “axis 1” represents columns
# find mode for categorical data columns (state)

# %%
#I decided to drop the column with unnamed (0)  
file1 = file1.drop('Unnamed: 0', axis=1)

# %%
file1.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
import numpy as np

# %%
# impute a value for the missing value (fill in a value that we choose or calculate)
# months since last claim
mean_Months_Since_Last_Claim = file1['Months Since Last Claim'].mean()
file1['Months Since Last Claim'] = file1['Months Since Last Claim'].fillna(mean_Months_Since_Last_Claim)

# %%
# Missing values can be imputed with a provided constant value, or using the statistics (mean, median or most frequent) of each column in which the missing values are located.
# number of open complaints
mean_Number_of_Open_Complaints = np.mean(file1)['Number of Open Complaints'].mean()
file1['Number of Open Complaints'] = file1['Number of Open Complaints'].fillna(mean_Number_of_Open_Complaints)

# %%
mean_Number_of_Open_Complaints = np.mean(file1)['Number of Open Complaints'].mean()
file1['Number of Open Complaints'] = file1['Number of Open Complaints'].fillna(mean_Number_of_Open_Complaints)

# %%
file1['State'].value_counts()
len(file1[file1['State'].isna()==True])
# Out:
# 631

# %%
file1['State'].value_counts()
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: State, dtype: int64

# %%
file1['State'] = file1['State'].fillna('California')

# %%
file1['Vehicle Class'].value_counts()
len(file1[file1['Vehicle Class'].isna()==True])
# Out:
# 622

# %%
file1['Vehicle Class'].value_counts()
# Out:
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: Vehicle Class, dtype: int64

# %%
file1['Vehicle Class'] = file1['Vehicle Class'].fillna('Four-Door Car')

# %%
file1['Vehicle Size'].value_counts()
len(file1[file1['Vehicle Size'].isna()==True])
# Out:
# 0

# %%
file1['Vehicle Size'].value_counts()
# Out:
# Medsize    7873
# Small      1966
# Large      1071
# Name: Vehicle Size, dtype: int64

# %%
file1['Vehicle Size'] = file1['Vehicle Size'].fillna('Medsize')

# %%
#from collections import counter
def response_rate(x):
  if x== "No":
    return 0
  else:
    return 1

file1['response Rate'] = list(map(response_rate,file1['Response']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Response'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-098f96d91cfc> in <module>
#       6     return 1
#       7
# ...

# %%
file1.isna().sum()
# Out:
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# response Rate                    0
# dtype: int64

# %%
file1._get_numeric_data()
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                     7.000000                             52
# 1                     3.000000                             26
# ...

# %%
file1 = file1.drop(['response'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-f9db6dd279fc> in <module>
# ----> 1 file1 = file1.drop(['response'], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
file1.isna().sum()
# Out:
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# response Rate                    0
# dtype: int64

# %%
# Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
import time
from datetime import date

today = date.today()
today
# Out:
# datetime.date(2021, 8, 15)

# %%
file1.to_csv('file1merged_clean_ver4.csv')

# %%
file1merged_clean_ver4=pd.read_csv('file1merged_clean_ver4.csv')

# %%
file1merged_clean_ver4
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value  Coverage  \
# 0               0  DK49336     Arizona              4809.216960     Basic
# 1               1  KX64629  California              2228.525238     Basic
# 2               2  LZ68649  Washington             14947.917300     Basic
# 3               3  XL78013      Oregon             22332.439460  Extended
# 4               4  QA50777      Oregon              9025.067525   Premium
# ...           ...      ...         ...                      ...       ...
# 10905       10905  FE99816      Nevada             15563.369440   Premium
# 10906       10906  KX53892      Oregon              5259.444853     Basic
# 10907       10907  TL39050     Arizona             23893.304100  Extended
# 10908       10908  WA60547  California             11971.977650   Premium
# 10909       10909  IV32877  California              6857.519928     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
file1merged_clean_ver4.isna().sum()
# Out:
# Unnamed: 0                       0
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# response Rate                    0
# dtype: int64

# %%
file1merged_clean_ver4 = file1merged_clean_ver4.drop('Unnamed: 0', axis=1)

# %%
file1merged_clean_ver4
# Out:
#       Customer       State  Customer Lifetime Value  Coverage Education  \
# 0      DK49336     Arizona              4809.216960     Basic   College
# 1      KX64629  California              2228.525238     Basic   College
# 2      LZ68649  Washington             14947.917300     Basic  Bachelor
# 3      XL78013      Oregon             22332.439460  Extended   College
# 4      QA50777      Oregon              9025.067525   Premium  Bachelor
# ...        ...         ...                      ...       ...       ...
# 10905  FE99816      Nevada             15563.369440   Premium  Bachelor
# 10906  KX53892      Oregon              5259.444853     Basic   College
# 10907  TL39050     Arizona             23893.304100  Extended  Bachelor
# 10908  WA60547  California             11971.977650   Premium   College
# 10909  IV32877  California              6857.519928     Basic  Bachelor
#
#       Effective To Date EmploymentStatus Gender  Income Location Code  ...  \
# ...

# %%
file1merged_clean_ver4.to_csv('file1merged_clean_ver5.csv')
