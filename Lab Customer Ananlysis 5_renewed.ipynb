# %%
import pandas as pd

# %%
marketing_customer_analysis_cleaned_lab5 = pd.read_csv('marketing_customer_analysis_cleaned_lab5.csv')

# %%
marketing_customer_analysis_cleaned_lab5 = marketing_customer_analysis_cleaned_lab5.drop('Unnamed: 0', axis=1)

# %%
marketing_customer_analysis_cleaned_lab5.head()
# Out:
#   Customer       State  Customer Lifetime Value  Coverage Education  \
# 0  DK49336     Arizona              4809.216960     Basic   College
# 1  KX64629  California              2228.525238     Basic   College
# 2  LZ68649  Washington             14947.917300     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460  Extended   College
# 4  QA50777      Oregon              9025.067525   Premium  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  ...  \
# 0           2/18/11         Employed      M   48029      Suburban  ...
# 1           1/18/11       Unemployed      F       0      Suburban  ...
# 2           2/10/11         Employed      M   22139      Suburban  ...
# 3           1/11/11         Employed      M   49078      Suburban  ...
# 4           1/17/11    Medical Leave      F   23675      Suburban  ...
#
#   Number of Open Complaints  Number of Policies     Policy Type        Policy  \
# ...

# %%
#Scale numericals (normalize)

# %%
numerical = marketing_customer_analysis_cleaned_lab5.select_dtypes(include = ['int64', 'float64']) 
categorical = marketing_customer_analysis_cleaned_lab5.select_dtypes(include = ['object'])

# %%
from sklearn.preprocessing import MinMaxScaler
MinMaxtransformer = MinMaxScaler().fit(numerical)
x_normalized = MinMaxtransformer.transform(numerical)
print(x_normalized.shape)
x_normalized = pd.DataFrame(x_normalized,columns=numerical.columns)
x_normalized.head()
# Out:
# (10910, 9)
#    Customer Lifetime Value    Income  Monthly Premium Auto  \
# 0                 0.035752  0.480381              0.000000
# 1                 0.004059  0.000000              0.012658
# 2                 0.160264  0.221432              0.164557
# 3                 0.250953  0.490873              0.151899
# 4                 0.087527  0.236795              0.236287
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                 0.200000                       0.525253
# 1                 0.085714                       0.262626
# 2                 0.971429                       0.313131
# 3                 0.285714                       0.030303
# 4                 0.432831                       0.313131
#
#    Number of Open Complaints  Number of Policies  Total Claim Amount  \
# 0                   0.000000               1.000            0.101171
# 1                   0.000000               0.000            0.257445
# ...

# %%
# X-y split

# %%
y = marketing_customer_analysis_cleaned_lab5['Total Claim Amount']
X = marketing_customer_analysis_cleaned_lab5.drop(['Total Claim Amount'], axis=1)
# I am not sure how to proceed. I will ask this Monday August 16

# %%
marketing_customer_analysis_cleaned_lab5.to_csv('marketing_customer_analysis_cleaned_lab6.csv')
